# %% [markdown]
# <a href="https://colab.research.google.com/github/etemadism/Courses/blob/main/02_Independent_Two_Samples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Statistical Analysis for Comparison of Two Independent Groups**
# ##Overview
# Welcome to the **Statistical Analysis** notebook for your statistics class. This notebook is designed to help you perform essential statistical analyses, including normality testing, variance equality checking, and hypothesis testing using the most suitable methods. It focuses on comparing the means of two groups (e.g., Male and Female) for multiple variables.
#
# ##Steps Covered:
#
# 1. Data Import: Load a CSV file containing your dataset.
#
# 2. Group Separation: Split the dataset based on a categorical variable (e.g., Gender).
#
# 3. Normality Testing: Check if each variable is normally distributed using either the Shapiro-Wilk or Kolmogorov-Smirnov test.
#
# 4. Levene’s Test: Check if the variances of the two groups are equal.
#
# 5. Hypothesis Testing:
#   * If data is normally distributed and variances are equal, use pooled t-test.
#
#   * If data is normally distributed but variances are unequal, use Welch's t-test.
#   * If data is not normally distributed, use the Mann-Whitney U test (non-parametric test).
#
# 6. Result Summary: Display and store a summary of the results, including p-values and statistical test outcomes.

# %% [markdown]
# **Data Availability**
#
# For learning purposes, you can access the dataset for this analysis on GitHub. The dataset is hosted on the GitHub account with the username **etemadism**. You can download the data directly from the repository to follow along with the notebook.
#
# GitHub Repository: https://github.com/etemadism
#
# **Author: Ali Etemadi**
#
# Tehran University of Medical Sciences, Tehran, Iran

# %% [markdown]
# ##Step 1: Import Libraries and define groups
# We'll use the scipy.stats library for the t-test and numpy for calculations.

# %%
from scipy import stats
import pandas as pd

# %% [markdown]
# ##Step 2: Define the Data
# Define the data for both groups.

# %%
# Step 1: Load the data from CSV
df = pd.read_csv('/content/02_inde_t_test_sample_data.csv')
df
# Out:
#      Total homocysteine  Methylmalonic acid  Total cysteine  Methionine  \
# 0             11.603118            0.380013      323.407760   32.147521
# 1              8.652174            0.216109      277.687527   30.547725
# 2             15.733290            1.328922      318.782237   32.815304
# 3             20.843928            0.199061      366.622622   26.772327
# 4             17.619270            0.408416      300.245602   35.448999
# ..                  ...                 ...             ...         ...
# 395           71.170973            0.156765      222.129076   23.078759
# 396           14.792811            0.356055      300.356735   23.894748
# 397           19.300000            2.259199      263.000000   26.516857
# 398            8.958233            0.184666      280.243136   38.371311
# 399           14.806169            0.309319      365.829387   27.503345
#
#          Serine     Glycine  Pyridoxal 5'-phosphate  Pyridoxal  \
# 0     94.332101  223.703485                    33.6       8.21
# 1    100.675469  258.799353                    26.0       3.08
# 2    110.969300  214.863843                    37.9      10.90
# 3    113.550372  523.362031                   215.0      19.20
# 4    139.728205  361.125581                    25.8       4.38
# ..          ...         ...                     ...        ...
# 395   70.869299  220.049433                    20.5       3.09
# 396  111.621847  353.777228                    51.5       6.88
# 397   98.528120  240.567659                    24.2       9.48
# 398  128.986231  277.599232                    39.5       9.50
# 399  116.563826  279.691447                    23.2       5.84
#
#      4-Pyridoxic acid  Pyridoxine  ...  N1-methylnicotinamide  Cystathionine  \
# 0               18.36           0  ...                   89.2          0.207
# 1               17.20           0  ...                   28.3          0.300
# 2               22.26           0  ...                  100.0          0.222
# 3               61.75           0  ...                   49.7          0.292
# 4               19.45           0  ...                  191.0          0.295
# ..                ...         ...  ...                    ...            ...
# 395             16.56           0  ...                   51.5          0.286
# 396             26.05           0  ...                  162.0          0.444
# 397             55.60           0  ...                   62.2          0.240
# 398             25.13           0  ...                  106.0          0.135
# 399             26.45           0  ...                   83.8          0.632
#
#      Trigonelline  5-Methyl-tetrahydrofolate  5-Formyl-tetrahydrofolate  \
# 0           0.450                      31.70                          0
# 1           0.327                      30.60                          0
# 2           0.112                      10.70                          0
# 3           0.797                      10.10                          0
# 4           0.909                      11.30                          0
# ..            ...                        ...                        ...
# 395         0.849                       3.23                          0
# 396         1.800                       5.48                          0
# 397         1.590                      26.00                          0
# 398         0.624                      19.30                          0
# 399         1.490                      34.60                          0
#
#      Folic acid  4-Alfa-hydroxy-5-methyl-THF  Para-aminobenzoylglutamate  \
# 0         0.631                         9.78                       0.823
# 1         0.000                         6.42                       0.863
# 2         0.000                         2.71                       0.507
# 3         0.000                         4.44                       0.970
# 4         0.000                         3.93                       0.390
# ..          ...                          ...                         ...
# 395       0.000                         4.04                       1.370
# 396       0.000                         2.32                       0.735
# 397       0.000                         5.03                       0.820
# 398       0.000                         4.23                       0.440
# 399       0.969                         6.08                       0.944
#
#      Acetamidobenzoylglutamate  Gender
# 0                        1.030  Female
# 1                        2.080  Female
# 2                        0.593    Male
# 3                        0.291  Female
# 4                        0.085    Male
# ..                         ...     ...
# 395                      0.085    Male
# 396                      0.085  Female
# 397                      0.376    Male
# 398                      0.249    Male
# 399                      0.443  Female
#
# [400 rows x 38 columns]

# %%
# Step 2: Recode the 'Gender' column (assuming Gender is represented as strings like 'Male' and 'Female')
df['Gender'] = df['Gender'].map({'Male': 0, 'Female': 1})  # Replace with correct values for Gender

# Step 3: Separate the data into two groups based on Gender (0 and 1)
group1 = df[df['Gender'] == 0]  # Male group
group2 = df[df['Gender'] == 1]  # Female group

# %%
df
# Out:
#      Total homocysteine  Methylmalonic acid  Total cysteine  Methionine  \
# 0             11.603118            0.380013      323.407760   32.147521
# 1              8.652174            0.216109      277.687527   30.547725
# 2             15.733290            1.328922      318.782237   32.815304
# 3             20.843928            0.199061      366.622622   26.772327
# 4             17.619270            0.408416      300.245602   35.448999
# ..                  ...                 ...             ...         ...
# 395           71.170973            0.156765      222.129076   23.078759
# 396           14.792811            0.356055      300.356735   23.894748
# 397           19.300000            2.259199      263.000000   26.516857
# 398            8.958233            0.184666      280.243136   38.371311
# 399           14.806169            0.309319      365.829387   27.503345
#
#          Serine     Glycine  Pyridoxal 5'-phosphate  Pyridoxal  \
# 0     94.332101  223.703485                    33.6       8.21
# 1    100.675469  258.799353                    26.0       3.08
# 2    110.969300  214.863843                    37.9      10.90
# 3    113.550372  523.362031                   215.0      19.20
# 4    139.728205  361.125581                    25.8       4.38
# ..          ...         ...                     ...        ...
# 395   70.869299  220.049433                    20.5       3.09
# 396  111.621847  353.777228                    51.5       6.88
# 397   98.528120  240.567659                    24.2       9.48
# 398  128.986231  277.599232                    39.5       9.50
# 399  116.563826  279.691447                    23.2       5.84
#
#      4-Pyridoxic acid  Pyridoxine  ...  N1-methylnicotinamide  Cystathionine  \
# 0               18.36           0  ...                   89.2          0.207
# 1               17.20           0  ...                   28.3          0.300
# 2               22.26           0  ...                  100.0          0.222
# 3               61.75           0  ...                   49.7          0.292
# 4               19.45           0  ...                  191.0          0.295
# ..                ...         ...  ...                    ...            ...
# 395             16.56           0  ...                   51.5          0.286
# 396             26.05           0  ...                  162.0          0.444
# 397             55.60           0  ...                   62.2          0.240
# 398             25.13           0  ...                  106.0          0.135
# 399             26.45           0  ...                   83.8          0.632
#
#      Trigonelline  5-Methyl-tetrahydrofolate  5-Formyl-tetrahydrofolate  \
# 0           0.450                      31.70                          0
# 1           0.327                      30.60                          0
# 2           0.112                      10.70                          0
# 3           0.797                      10.10                          0
# 4           0.909                      11.30                          0
# ..            ...                        ...                        ...
# 395         0.849                       3.23                          0
# 396         1.800                       5.48                          0
# 397         1.590                      26.00                          0
# 398         0.624                      19.30                          0
# 399         1.490                      34.60                          0
#
#      Folic acid  4-Alfa-hydroxy-5-methyl-THF  Para-aminobenzoylglutamate  \
# 0         0.631                         9.78                       0.823
# 1         0.000                         6.42                       0.863
# 2         0.000                         2.71                       0.507
# 3         0.000                         4.44                       0.970
# 4         0.000                         3.93                       0.390
# ..          ...                          ...                         ...
# 395       0.000                         4.04                       1.370
# 396       0.000                         2.32                       0.735
# 397       0.000                         5.03                       0.820
# 398       0.000                         4.23                       0.440
# 399       0.969                         6.08                       0.944
#
#      Acetamidobenzoylglutamate  Gender
# 0                        1.030       1
# 1                        2.080       1
# 2                        0.593       0
# 3                        0.291       1
# 4                        0.085       0
# ..                         ...     ...
# 395                      0.085       0
# 396                      0.085       1
# 397                      0.376       0
# 398                      0.249       0
# 399                      0.443       1
#
# [400 rows x 38 columns]

# %%
# Step 4: Define variables as columns 1 to 8 (assuming these are the first 8 columns after 'Gender')
variables = df.columns[0:37]  # Selecting the first 8 columns

# %%
# Function to select normality test based on sample size
def normality_test(data, threshold=50):
    """Perform Shapiro-Wilk if n < threshold, otherwise Kolmogorov-Smirnov."""
    n = len(data)
    if n < threshold:
        stat, p_value = stats.shapiro(data)
        test = "Shapiro-Wilk"
    else:
        stat, p_value = stats.kstest(data, 'norm')
        test = "Kolmogorov-Smirnov"
    return test, stat, p_value

# %%
# Step 5: Perform Levene’s Test for each variable (check for equal variances)
for variable in variables:
    # Extract data for the current variable
    data_group1 = group1[variable]
    data_group2 = group2[variable]

    # Perform Levene's test for equality of variances
    levene_stat, levene_p = stats.levene(data_group1, data_group2)

    print(f'--- Levene’s Test for {variable} ---')
    print(f"Levene's test statistic: {levene_stat:.4f}, p-value: {levene_p:.4f}")

    # Perform normality test (choose based on sample size)
    test1, shapiro_group1_stat, shapiro_group1_p = normality_test(data_group1)
    test2, shapiro_group2_stat, shapiro_group2_p = normality_test(data_group2)

    print(f"Normality test on Group 1 using {test1}: p-value = {shapiro_group1_p:.4f}")
    print(f"Normality test on Group 2 using {test2}: p-value = {shapiro_group2_p:.4f}")

    # Check if data is normal, if not perform Mann-Whitney U test (non-parametric)
    if shapiro_group1_p < 0.05 or shapiro_group2_p < 0.05:
        print("Data is not normal, performing Mann-Whitney U test (non-parametric).")
        # Perform Mann-Whitney U test
        stat, p_value = stats.mannwhitneyu(data_group1, data_group2)
        print(f'Mann-Whitney U test result for {variable}:')
        print(f'U-statistic: {stat:.4f}, p-value: {p_value:.4f}')
    else:
        # If data is normal, proceed with t-test
        if levene_p > 0.05:
            print("Equal variances assumed, proceed with pooled t-test.")
            stat, p_value = stats.ttest_ind(data_group1, data_group2, equal_var=True)
        else:
            print("Unequal variances assumed, proceed with Welch’s t-test.")
            stat, p_value = stats.ttest_ind(data_group1, data_group2, equal_var=False)

        print(f'Independent T-test result for {variable}:')
        print(f'T-statistic: {stat:.4f}, p-value: {p_value:.4f}')

    # Check if the p-value is significant
    if p_value < 0.05:
        print(f'Significant difference between Group 1 and Group 2 for {variable} (reject H0)')
    else:
        print(f'No significant difference between Group 1 and Group 2 for {variable} (fail to reject H0)')

    print('------------------------------------')
# Out:
# --- Levene’s Test for Total homocysteine ---
# Levene's test statistic: 3.8371, p-value: 0.0508
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Total homocysteine:
# U-statistic: 25377.0000, p-value: 0.0000
# Significant difference between Group 1 and Group 2 for Total homocysteine (reject H0)
# ------------------------------------
# --- Levene’s Test for Methylmalonic acid ---
# Levene's test statistic: 0.0035, p-value: 0.9530
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Methylmalonic acid:
# U-statistic: 23678.0000, p-value: 0.0011
# Significant difference between Group 1 and Group 2 for Methylmalonic acid (reject H0)
# ------------------------------------
# --- Levene’s Test for Total cysteine ---
# Levene's test statistic: 4.8961, p-value: 0.0275
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Total cysteine:
# U-statistic: 16626.0000, p-value: 0.0045
# Significant difference between Group 1 and Group 2 for Total cysteine (reject H0)
# ------------------------------------
# --- Levene’s Test for Methionine ---
# Levene's test statistic: 3.3495, p-value: 0.0680
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Methionine:
# U-statistic: 30097.0000, p-value: 0.0000
# Significant difference between Group 1 and Group 2 for Methionine (reject H0)
# ------------------------------------
# --- Levene’s Test for Serine ---
# Levene's test statistic: 1.9774, p-value: 0.1604
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Serine:
# U-statistic: 21180.0000, p-value: 0.2680
# No significant difference between Group 1 and Group 2 for Serine (fail to reject H0)
# ------------------------------------
# --- Levene’s Test for Glycine ---
# Levene's test statistic: 17.8905, p-value: 0.0000
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Glycine:
# U-statistic: 16072.0000, p-value: 0.0009
# Significant difference between Group 1 and Group 2 for Glycine (reject H0)
# ------------------------------------
# --- Levene’s Test for Pyridoxal 5'-phosphate ---
# Levene's test statistic: 0.4410, p-value: 0.5070
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Pyridoxal 5'-phosphate:
# U-statistic: 22065.5000, p-value: 0.0607
# No significant difference between Group 1 and Group 2 for Pyridoxal 5'-phosphate (fail to reject H0)
# ------------------------------------
# --- Levene’s Test for Pyridoxal ---
# Levene's test statistic: 0.3626, p-value: 0.5474
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Pyridoxal:
# U-statistic: 24160.5000, p-value: 0.0002
# Significant difference between Group 1 and Group 2 for Pyridoxal (reject H0)
# ------------------------------------
# --- Levene’s Test for 4-Pyridoxic acid ---
# Levene's test statistic: 0.1669, p-value: 0.6831
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for 4-Pyridoxic acid:
# U-statistic: 20672.5000, p-value: 0.5044
# No significant difference between Group 1 and Group 2 for 4-Pyridoxic acid (fail to reject H0)
# ------------------------------------
# --- Levene’s Test for Pyridoxine ---
# Levene's test statistic: nan, p-value: nan
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Pyridoxine:
# U-statistic: 19902.0000, p-value: 1.0000
# No significant difference between Group 1 and Group 2 for Pyridoxine (fail to reject H0)
# ------------------------------------
# --- Levene’s Test for Thiamine ---
# Levene's test statistic: 1.5933, p-value: 0.2076
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Thiamine:
# U-statistic: 14611.0000, p-value: 0.0000
# Significant difference between Group 1 and Group 2 for Thiamine (reject H0)
# ------------------------------------
# --- Levene’s Test for Thiamine monophosphate ---
# Levene's test statistic: 0.3029, p-value: 0.5824
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Thiamine monophosphate:
# U-statistic: 16661.0000, p-value: 0.0050
# Significant difference between Group 1 and Group 2 for Thiamine monophosphate (reject H0)
# ------------------------------------
# --- Levene’s Test for Riboflavin ---
# Levene's test statistic: 0.7861, p-value: 0.3758
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Riboflavin:
# U-statistic: 20402.5000, p-value: 0.6646
# No significant difference between Group 1 and Group 2 for Riboflavin (fail to reject H0)
# ------------------------------------
# --- Levene’s Test for Flavin mononucleotide ---
# Levene's test statistic: 2.1485, p-value: 0.1435
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Flavin mononucleotide:
# U-statistic: 20887.5000, p-value: 0.3931
# No significant difference between Group 1 and Group 2 for Flavin mononucleotide (fail to reject H0)
# ------------------------------------
# --- Levene’s Test for Neopterin ---
# Levene's test statistic: 1.1377, p-value: 0.2868
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Neopterin:
# U-statistic: 18690.0000, p-value: 0.2935
# No significant difference between Group 1 and Group 2 for Neopterin (fail to reject H0)
# ------------------------------------
# --- Levene’s Test for Cotinine ---
# Levene's test statistic: nan, p-value: nan
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = nan
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Cotinine:
# U-statistic: nan, p-value: nan
# No significant difference between Group 1 and Group 2 for Cotinine (fail to reject H0)
# ------------------------------------
# --- Levene’s Test for Trans-3'-hydroxycotinine ---
# Levene's test statistic: 1.6977, p-value: 0.1933
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Trans-3'-hydroxycotinine:
# U-statistic: 20148.5000, p-value: 0.7895
# No significant difference between Group 1 and Group 2 for Trans-3'-hydroxycotinine (fail to reject H0)
# ------------------------------------
# --- Levene’s Test for Tryptophan ---
# Levene's test statistic: 0.0899, p-value: 0.7644
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Tryptophan:
# U-statistic: 26255.0000, p-value: 0.0000
# Significant difference between Group 1 and Group 2 for Tryptophan (reject H0)
# ------------------------------------
# --- Levene’s Test for Kynurenine ---
# Levene's test statistic: 2.2772, p-value: 0.1321
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:3345: RuntimeWarning: invalid value encountered in scalar divide
#   W = numer / denom
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Kynurenine:
# U-statistic: 20806.0000, p-value: 0.4334
# No significant difference between Group 1 and Group 2 for Kynurenine (fail to reject H0)
# ------------------------------------
# --- Levene’s Test for 3-Hydroxykynurenine ---
# Levene's test statistic: 5.5401, p-value: 0.0191
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for 3-Hydroxykynurenine:
# U-statistic: 18093.5000, p-value: 0.1170
# No significant difference between Group 1 and Group 2 for 3-Hydroxykynurenine (fail to reject H0)
# ------------------------------------
# --- Levene’s Test for Kynurenic acid ---
# Levene's test statistic: 0.0628, p-value: 0.8022
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Kynurenic acid:
# U-statistic: 23143.5000, p-value: 0.0050
# Significant difference between Group 1 and Group 2 for Kynurenic acid (reject H0)
# ------------------------------------
# --- Levene’s Test for Xanthurenic acid ---
# Levene's test statistic: 3.1188, p-value: 0.0782
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Xanthurenic acid:
# U-statistic: 27581.5000, p-value: 0.0000
# Significant difference between Group 1 and Group 2 for Xanthurenic acid (reject H0)
# ------------------------------------
# --- Levene’s Test for Anthranilic acid ---
# Levene's test statistic: 0.4995, p-value: 0.4802
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Anthranilic acid:
# U-statistic: 20448.5000, p-value: 0.6359
# No significant difference between Group 1 and Group 2 for Anthranilic acid (fail to reject H0)
# ------------------------------------
# --- Levene’s Test for 3-Hydroxyanthranilic acid ---
# Levene's test statistic: 2.2354, p-value: 0.1357
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for 3-Hydroxyanthranilic acid:
# U-statistic: 27794.0000, p-value: 0.0000
# Significant difference between Group 1 and Group 2 for 3-Hydroxyanthranilic acid (reject H0)
# ------------------------------------
# --- Levene’s Test for Picolinic acid ---
# Levene's test statistic: 0.4222, p-value: 0.5162
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Picolinic acid:
# U-statistic: 27980.5000, p-value: 0.0000
# Significant difference between Group 1 and Group 2 for Picolinic acid (reject H0)
# ------------------------------------
# --- Levene’s Test for Quinolinic acid ---
# Levene's test statistic: 2.0357, p-value: 0.1544
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Quinolinic acid:
# U-statistic: 19905.0000, p-value: 0.9983
# No significant difference between Group 1 and Group 2 for Quinolinic acid (fail to reject H0)
# ------------------------------------
# --- Levene’s Test for Nicotinic acid ---
# Levene's test statistic: nan, p-value: nan
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Nicotinic acid:
# U-statistic: 19902.0000, p-value: 1.0000
# No significant difference between Group 1 and Group 2 for Nicotinic acid (fail to reject H0)
# ------------------------------------
# --- Levene’s Test for Nicotinamide ---
# Levene's test statistic: 6.5400, p-value: 0.0109
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Nicotinamide:
# U-statistic: 24465.5000, p-value: 0.0001
# Significant difference between Group 1 and Group 2 for Nicotinamide (reject H0)
# ------------------------------------
# --- Levene’s Test for N1-methylnicotinamide ---
# Levene's test statistic: 4.9142, p-value: 0.0272
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for N1-methylnicotinamide:
# U-statistic: 21794.0000, p-value: 0.1010
# No significant difference between Group 1 and Group 2 for N1-methylnicotinamide (fail to reject H0)
# ------------------------------------
# --- Levene’s Test for Cystathionine ---
# Levene's test statistic: 0.0696, p-value: 0.7920
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Cystathionine:
# U-statistic: 22966.0000, p-value: 0.0079
# Significant difference between Group 1 and Group 2 for Cystathionine (reject H0)
# ------------------------------------
# --- Levene’s Test for Trigonelline ---
# Levene's test statistic: 0.3452, p-value: 0.5572
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Trigonelline:
# U-statistic: 20573.0000, p-value: 0.5610
# No significant difference between Group 1 and Group 2 for Trigonelline (fail to reject H0)
# ------------------------------------
# --- Levene’s Test for 5-Methyl-tetrahydrofolate ---
# Levene's test statistic: 4.8329, p-value: 0.0285
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for 5-Methyl-tetrahydrofolate:
# U-statistic: 17920.0000, p-value: 0.0858
# No significant difference between Group 1 and Group 2 for 5-Methyl-tetrahydrofolate (fail to reject H0)
# ------------------------------------
# --- Levene’s Test for 5-Formyl-tetrahydrofolate ---
# Levene's test statistic: nan, p-value: nan
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for 5-Formyl-tetrahydrofolate:
# U-statistic: 19902.0000, p-value: 1.0000
# No significant difference between Group 1 and Group 2 for 5-Formyl-tetrahydrofolate (fail to reject H0)
# ------------------------------------
# --- Levene’s Test for Folic acid ---
# Levene's test statistic: 3.7895, p-value: 0.0523
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Folic acid:
# U-statistic: 19408.0000, p-value: 0.4713
# No significant difference between Group 1 and Group 2 for Folic acid (fail to reject H0)
# ------------------------------------
# --- Levene’s Test for 4-Alfa-hydroxy-5-methyl-THF ---
# Levene's test statistic: 2.3731, p-value: 0.1242
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for 4-Alfa-hydroxy-5-methyl-THF:
# U-statistic: 19667.5000, p-value: 0.8392
# No significant difference between Group 1 and Group 2 for 4-Alfa-hydroxy-5-methyl-THF (fail to reject H0)
# ------------------------------------
# --- Levene’s Test for Para-aminobenzoylglutamate ---
# Levene's test statistic: 2.5373, p-value: 0.1120
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Para-aminobenzoylglutamate:
# U-statistic: 20856.5000, p-value: 0.4081
# No significant difference between Group 1 and Group 2 for Para-aminobenzoylglutamate (fail to reject H0)
# ------------------------------------
# --- Levene’s Test for Acetamidobenzoylglutamate ---
# Levene's test statistic: 1.1165, p-value: 0.2913
# Normality test on Group 1 using Kolmogorov-Smirnov: p-value = 0.0000
# Normality test on Group 2 using Kolmogorov-Smirnov: p-value = 0.0000
# Data is not normal, performing Mann-Whitney U test (non-parametric).
# Mann-Whitney U test result for Acetamidobenzoylglutamate:
# U-statistic: 18979.5000, p-value: 0.4207
# No significant difference between Group 1 and Group 2 for Acetamidobenzoylglutamate (fail to reject H0)
# ------------------------------------

# %% [markdown]
# ##Step 3: Check for Equal Variances (Levene’s Test) and Perform the Independent Two-Sample t-Test
# Levene’s test checks if the variances of the two groups are equal. This will determine if we should use the pooled t-test or Welch’s t-test.

# %% [markdown]
# If the p-value is greater than 0.05, we assume equal variances and proceed with the pooled t-test.
# If the p-value is less than 0.05, we assume unequal variances and use Welch’s t-test.

# %%
# Step 5: Create an empty list to store results
results = []

# Perform normality test, Levene’s Test, and t-tests for each variable (check for normality, equality of variances)
for variable in variables:
    # Extract data for the current variable
    data_group1 = group1[variable]
    data_group2 = group2[variable]

    # Step 5.1: Perform normality test for each group
    normality_group1 = normality_test(data_group1)
    normality_group2 = normality_test(data_group2)

    # Print normality test results
    print(f'--- Normality Test for {variable} ---')
    print(f'Group 1 ({variable}) - Test: {normality_group1[0]}, Stat: {normality_group1[1]:.4f}, p-value: {normality_group1[2]:.4f}')
    print(f'Group 2 ({variable}) - Test: {normality_group2[0]}, Stat: {normality_group2[1]:.4f}, p-value: {normality_group2[2]:.4f}')

    # Step 5.2: Check if data are normal (p-value < 0.05 means not normal)
    if normality_group1[2] < 0.05 or normality_group2[2] < 0.05:
        print("Data is not normally distributed, using Mann-Whitney U Test.")
        # Mann-Whitney U test (non-parametric test for independent samples)
        stat, p_value = stats.mannwhitneyu(data_group1, data_group2)
        test_type = "Mann-Whitney U Test"
    else:
        # Perform Levene's test for equality of variances
        levene_stat, levene_p = stats.levene(data_group1, data_group2)

        print(f'--- Levene’s Test for {variable} ---')
        print(f"Levene's test statistic: {levene_stat:.4f}, p-value: {levene_p:.4f}")

        # If Levene's test shows p-value > 0.05, variances are equal (use pooled t-test), else use Welch's t-test
        if levene_p > 0.05:
            print("Equal variances assumed, proceed with pooled t-test.")
            stat, p_value = stats.ttest_ind(data_group1, data_group2, equal_var=True)
            test_type = "Pooled T-test (Equal variances)"
        else:
            print("Unequal variances assumed, proceed with Welch’s t-test.")
            stat, p_value = stats.ttest_ind(data_group1, data_group2, equal_var=False)
            test_type = "Welch's T-test (Unequal variances)"

    # Print the test result
    print(f'{test_type} result for {variable}:')
    print(f'T-statistic/U-statistic: {stat:.4f}, p-value: {p_value:.4f}')

    # Check if the p-value is significant
    if p_value < 0.05:
        significance = 'Significant'
        print(f'Significant difference between Group 1 and Group 2 for {variable} (reject H0)')
    else:
        significance = 'Not Significant'
        print(f'No significant difference between Group 1 and Group 2 for {variable} (fail to reject H0)')

    print('------------------------------------')

    # Step 6: Store the results for the table
    results.append({
        'Variable': variable,
        'Normality Test Group 1': normality_group1[0],
        'Normality p-value Group 1': round(normality_group1[2], 4),
        'Normality Test Group 2': normality_group2[0],
        'Normality p-value Group 2': round(normality_group2[2], 4),
        'Levene Statistic': round(levene_stat, 4) if 'levene_stat' in locals() else None,
        'Levene p-value': round(levene_p, 4) if 'levene_p' in locals() else None,
        'Test Type': test_type,
        'Test Statistic': round(stat, 4),
        'p-value': round(p_value, 4),
        'Significance': significance
    })

# Step 7: Create a DataFrame for the results table
results_df = pd.DataFrame(results)

# Step 8: Print the results table
print("Final Report Summary:")
results_df

# Optional: Save the results table to a CSV file
#results_df.to_csv('test_results_report.csv', index=False)
# Out:
# --- Normality Test for Total homocysteine ---
# Group 1 (Total homocysteine) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Group 2 (Total homocysteine) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Total homocysteine:
# T-statistic/U-statistic: 25377.0000, p-value: 0.0000
# Significant difference between Group 1 and Group 2 for Total homocysteine (reject H0)
# ------------------------------------
# --- Normality Test for Methylmalonic acid ---
# Group 1 (Methylmalonic acid) - Test: Kolmogorov-Smirnov, Stat: 0.5434, p-value: 0.0000
# Group 2 (Methylmalonic acid) - Test: Kolmogorov-Smirnov, Stat: 0.5409, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Methylmalonic acid:
# T-statistic/U-statistic: 23678.0000, p-value: 0.0011
# Significant difference between Group 1 and Group 2 for Methylmalonic acid (reject H0)
# ------------------------------------
# --- Normality Test for Total cysteine ---
# Group 1 (Total cysteine) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Group 2 (Total cysteine) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Total cysteine:
# T-statistic/U-statistic: 16626.0000, p-value: 0.0045
# Significant difference between Group 1 and Group 2 for Total cysteine (reject H0)
# ------------------------------------
# --- Normality Test for Methionine ---
# Group 1 (Methionine) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Group 2 (Methionine) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Methionine:
# T-statistic/U-statistic: 30097.0000, p-value: 0.0000
# Significant difference between Group 1 and Group 2 for Methionine (reject H0)
# ------------------------------------
# --- Normality Test for Serine ---
# Group 1 (Serine) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Group 2 (Serine) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Serine:
# T-statistic/U-statistic: 21180.0000, p-value: 0.2680
# No significant difference between Group 1 and Group 2 for Serine (fail to reject H0)
# ------------------------------------
# --- Normality Test for Glycine ---
# Group 1 (Glycine) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Group 2 (Glycine) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Glycine:
# T-statistic/U-statistic: 16072.0000, p-value: 0.0009
# Significant difference between Group 1 and Group 2 for Glycine (reject H0)
# ------------------------------------
# --- Normality Test for Pyridoxal 5'-phosphate ---
# Group 1 (Pyridoxal 5'-phosphate) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Group 2 (Pyridoxal 5'-phosphate) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Pyridoxal 5'-phosphate:
# T-statistic/U-statistic: 22065.5000, p-value: 0.0607
# No significant difference between Group 1 and Group 2 for Pyridoxal 5'-phosphate (fail to reject H0)
# ------------------------------------
# --- Normality Test for Pyridoxal ---
# Group 1 (Pyridoxal) - Test: Kolmogorov-Smirnov, Stat: 0.9990, p-value: 0.0000
# Group 2 (Pyridoxal) - Test: Kolmogorov-Smirnov, Stat: 0.9972, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Pyridoxal:
# T-statistic/U-statistic: 24160.5000, p-value: 0.0002
# Significant difference between Group 1 and Group 2 for Pyridoxal (reject H0)
# ------------------------------------
# --- Normality Test for 4-Pyridoxic acid ---
# Group 1 (4-Pyridoxic acid) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Group 2 (4-Pyridoxic acid) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for 4-Pyridoxic acid:
# T-statistic/U-statistic: 20672.5000, p-value: 0.5044
# No significant difference between Group 1 and Group 2 for 4-Pyridoxic acid (fail to reject H0)
# ------------------------------------
# --- Normality Test for Pyridoxine ---
# Group 1 (Pyridoxine) - Test: Kolmogorov-Smirnov, Stat: 0.5000, p-value: 0.0000
# Group 2 (Pyridoxine) - Test: Kolmogorov-Smirnov, Stat: 0.5000, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Pyridoxine:
# T-statistic/U-statistic: 19902.0000, p-value: 1.0000
# No significant difference between Group 1 and Group 2 for Pyridoxine (fail to reject H0)
# ------------------------------------
# --- Normality Test for Thiamine ---
# Group 1 (Thiamine) - Test: Kolmogorov-Smirnov, Stat: 0.7878, p-value: 0.0000
# Group 2 (Thiamine) - Test: Kolmogorov-Smirnov, Stat: 0.8316, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Thiamine:
# T-statistic/U-statistic: 14611.0000, p-value: 0.0000
# Significant difference between Group 1 and Group 2 for Thiamine (reject H0)
# ------------------------------------
# --- Normality Test for Thiamine monophosphate ---
# Group 1 (Thiamine monophosphate) - Test: Kolmogorov-Smirnov, Stat: 0.9862, p-value: 0.0000
# Group 2 (Thiamine monophosphate) - Test: Kolmogorov-Smirnov, Stat: 0.9992, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Thiamine monophosphate:
# T-statistic/U-statistic: 16661.0000, p-value: 0.0050
# Significant difference between Group 1 and Group 2 for Thiamine monophosphate (reject H0)
# ------------------------------------
# --- Normality Test for Riboflavin ---
# Group 1 (Riboflavin) - Test: Kolmogorov-Smirnov, Stat: 0.9564, p-value: 0.0000
# Group 2 (Riboflavin) - Test: Kolmogorov-Smirnov, Stat: 0.9191, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Riboflavin:
# T-statistic/U-statistic: 20402.5000, p-value: 0.6646
# No significant difference between Group 1 and Group 2 for Riboflavin (fail to reject H0)
# ------------------------------------
# --- Normality Test for Flavin mononucleotide ---
# Group 1 (Flavin mononucleotide) - Test: Kolmogorov-Smirnov, Stat: 0.9994, p-value: 0.0000
# Group 2 (Flavin mononucleotide) - Test: Kolmogorov-Smirnov, Stat: 0.9991, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Flavin mononucleotide:
# T-statistic/U-statistic: 20887.5000, p-value: 0.3931
# No significant difference between Group 1 and Group 2 for Flavin mononucleotide (fail to reject H0)
# ------------------------------------
# --- Normality Test for Neopterin ---
# Group 1 (Neopterin) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Group 2 (Neopterin) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Neopterin:
# T-statistic/U-statistic: 18690.0000, p-value: 0.2935
# No significant difference between Group 1 and Group 2 for Neopterin (fail to reject H0)
# ------------------------------------
# --- Normality Test for Cotinine ---
# Group 1 (Cotinine) - Test: Kolmogorov-Smirnov, Stat: 0.5000, p-value: 0.0000
# Group 2 (Cotinine) - Test: Kolmogorov-Smirnov, Stat: nan, p-value: nan
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Cotinine:
# T-statistic/U-statistic: nan, p-value: nan
# No significant difference between Group 1 and Group 2 for Cotinine (fail to reject H0)
# ------------------------------------
# --- Normality Test for Trans-3'-hydroxycotinine ---
# Group 1 (Trans-3'-hydroxycotinine) - Test: Kolmogorov-Smirnov, Stat: 0.5000, p-value: 0.0000
# Group 2 (Trans-3'-hydroxycotinine) - Test: Kolmogorov-Smirnov, Stat: 0.5000, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Trans-3'-hydroxycotinine:
# T-statistic/U-statistic: 20148.5000, p-value: 0.7895
# No significant difference between Group 1 and Group 2 for Trans-3'-hydroxycotinine (fail to reject H0)
# ------------------------------------
# --- Normality Test for Tryptophan ---
# Group 1 (Tryptophan) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Group 2 (Tryptophan) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Tryptophan:
# T-statistic/U-statistic: 26255.0000, p-value: 0.0000
# Significant difference between Group 1 and Group 2 for Tryptophan (reject H0)
# ------------------------------------
# --- Normality Test for Kynurenine ---
# Group 1 (Kynurenine) - Test: Kolmogorov-Smirnov, Stat: 0.8726, p-value: 0.0000
# Group 2 (Kynurenine) - Test: Kolmogorov-Smirnov, Stat: 0.8313, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Kynurenine:
# T-statistic/U-statistic: 20806.0000, p-value: 0.4334
# No significant difference between Group 1 and Group 2 for Kynurenine (fail to reject H0)
# ------------------------------------
# --- Normality Test for 3-Hydroxykynurenine ---
# Group 1 (3-Hydroxykynurenine) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Group 2 (3-Hydroxykynurenine) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for 3-Hydroxykynurenine:
# T-statistic/U-statistic: 18093.5000, p-value: 0.1170
# No significant difference between Group 1 and Group 2 for 3-Hydroxykynurenine (fail to reject H0)
# ------------------------------------
# --- Normality Test for Kynurenic acid ---
# Group 1 (Kynurenic acid) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Group 2 (Kynurenic acid) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Kynurenic acid:
# T-statistic/U-statistic: 23143.5000, p-value: 0.0050
# Significant difference between Group 1 and Group 2 for Kynurenic acid (reject H0)
# ------------------------------------
# --- Normality Test for Xanthurenic acid ---
# Group 1 (Xanthurenic acid) - Test: Kolmogorov-Smirnov, Stat: 0.9887, p-value: 0.0000
# Group 2 (Xanthurenic acid) - Test: Kolmogorov-Smirnov, Stat: 0.9937, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Xanthurenic acid:
# T-statistic/U-statistic: 27581.5000, p-value: 0.0000
# Significant difference between Group 1 and Group 2 for Xanthurenic acid (reject H0)
# ------------------------------------
# --- Normality Test for Anthranilic acid ---
# Group 1 (Anthranilic acid) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Group 2 (Anthranilic acid) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Anthranilic acid:
# T-statistic/U-statistic: 20448.5000, p-value: 0.6359
# No significant difference between Group 1 and Group 2 for Anthranilic acid (fail to reject H0)
# ------------------------------------
# --- Normality Test for 3-Hydroxyanthranilic acid ---
# Group 1 (3-Hydroxyanthranilic acid) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Group 2 (3-Hydroxyanthranilic acid) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for 3-Hydroxyanthranilic acid:
# T-statistic/U-statistic: 27794.0000, p-value: 0.0000
# Significant difference between Group 1 and Group 2 for 3-Hydroxyanthranilic acid (reject H0)
# ------------------------------------
# --- Normality Test for Picolinic acid ---
# Group 1 (Picolinic acid) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Group 2 (Picolinic acid) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Picolinic acid:
# T-statistic/U-statistic: 27980.5000, p-value: 0.0000
# Significant difference between Group 1 and Group 2 for Picolinic acid (reject H0)
# ------------------------------------
# --- Normality Test for Quinolinic acid ---
# Group 1 (Quinolinic acid) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Group 2 (Quinolinic acid) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Quinolinic acid:
# T-statistic/U-statistic: 19905.0000, p-value: 0.9983
# No significant difference between Group 1 and Group 2 for Quinolinic acid (fail to reject H0)
# ------------------------------------
# --- Normality Test for Nicotinic acid ---
# Group 1 (Nicotinic acid) - Test: Kolmogorov-Smirnov, Stat: 0.5000, p-value: 0.0000
# Group 2 (Nicotinic acid) - Test: Kolmogorov-Smirnov, Stat: 0.5000, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Nicotinic acid:
# T-statistic/U-statistic: 19902.0000, p-value: 1.0000
# No significant difference between Group 1 and Group 2 for Nicotinic acid (fail to reject H0)
# ------------------------------------
# --- Normality Test for Nicotinamide ---
# Group 1 (Nicotinamide) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Group 2 (Nicotinamide) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Nicotinamide:
# T-statistic/U-statistic: 24465.5000, p-value: 0.0001
# Significant difference between Group 1 and Group 2 for Nicotinamide (reject H0)
# ------------------------------------
# --- Normality Test for N1-methylnicotinamide ---
# Group 1 (N1-methylnicotinamide) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Group 2 (N1-methylnicotinamide) - Test: Kolmogorov-Smirnov, Stat: 1.0000, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for N1-methylnicotinamide:
# T-statistic/U-statistic: 21794.0000, p-value: 0.1010
# No significant difference between Group 1 and Group 2 for N1-methylnicotinamide (fail to reject H0)
# ------------------------------------
# --- Normality Test for Cystathionine ---
# Group 1 (Cystathionine) - Test: Kolmogorov-Smirnov, Stat: 0.5483, p-value: 0.0000
# Group 2 (Cystathionine) - Test: Kolmogorov-Smirnov, Stat: 0.5387, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Cystathionine:
# T-statistic/U-statistic: 22966.0000, p-value: 0.0079
# Significant difference between Group 1 and Group 2 for Cystathionine (reject H0)
# ------------------------------------
# --- Normality Test for Trigonelline ---
# Group 1 (Trigonelline) - Test: Kolmogorov-Smirnov, Stat: 0.5248, p-value: 0.0000
# Group 2 (Trigonelline) - Test: Kolmogorov-Smirnov, Stat: 0.5415, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Trigonelline:
# T-statistic/U-statistic: 20573.0000, p-value: 0.5610
# No significant difference between Group 1 and Group 2 for Trigonelline (fail to reject H0)
# ------------------------------------
# --- Normality Test for 5-Methyl-tetrahydrofolate ---
# Group 1 (5-Methyl-tetrahydrofolate) - Test: Kolmogorov-Smirnov, Stat: 0.9990, p-value: 0.0000
# Group 2 (5-Methyl-tetrahydrofolate) - Test: Kolmogorov-Smirnov, Stat: 0.9999, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for 5-Methyl-tetrahydrofolate:
# T-statistic/U-statistic: 17920.0000, p-value: 0.0858
# No significant difference between Group 1 and Group 2 for 5-Methyl-tetrahydrofolate (fail to reject H0)
# ------------------------------------
# --- Normality Test for 5-Formyl-tetrahydrofolate ---
# Group 1 (5-Formyl-tetrahydrofolate) - Test: Kolmogorov-Smirnov, Stat: 0.5000, p-value: 0.0000
# Group 2 (5-Formyl-tetrahydrofolate) - Test: Kolmogorov-Smirnov, Stat: 0.5000, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for 5-Formyl-tetrahydrofolate:
# T-statistic/U-statistic: 19902.0000, p-value: 1.0000
# No significant difference between Group 1 and Group 2 for 5-Formyl-tetrahydrofolate (fail to reject H0)
# ------------------------------------
# --- Normality Test for Folic acid ---
# Group 1 (Folic acid) - Test: Kolmogorov-Smirnov, Stat: 0.5000, p-value: 0.0000
# Group 2 (Folic acid) - Test: Kolmogorov-Smirnov, Stat: 0.5000, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Folic acid:
# T-statistic/U-statistic: 19408.0000, p-value: 0.4713
# No significant difference between Group 1 and Group 2 for Folic acid (fail to reject H0)
# ------------------------------------
# --- Normality Test for 4-Alfa-hydroxy-5-methyl-THF ---
# Group 1 (4-Alfa-hydroxy-5-methyl-THF) - Test: Kolmogorov-Smirnov, Stat: 0.9372, p-value: 0.0000
# Group 2 (4-Alfa-hydroxy-5-methyl-THF) - Test: Kolmogorov-Smirnov, Stat: 0.9486, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for 4-Alfa-hydroxy-5-methyl-THF:
# T-statistic/U-statistic: 19667.5000, p-value: 0.8392
# No significant difference between Group 1 and Group 2 for 4-Alfa-hydroxy-5-methyl-THF (fail to reject H0)
# ------------------------------------
# --- Normality Test for Para-aminobenzoylglutamate ---
# Group 1 (Para-aminobenzoylglutamate) - Test: Kolmogorov-Smirnov, Stat: 0.5784, p-value: 0.0000
# Group 2 (Para-aminobenzoylglutamate) - Test: Kolmogorov-Smirnov, Stat: 0.5543, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Para-aminobenzoylglutamate:
# T-statistic/U-statistic: 20856.5000, p-value: 0.4081
# No significant difference between Group 1 and Group 2 for Para-aminobenzoylglutamate (fail to reject H0)
# ------------------------------------
# --- Normality Test for Acetamidobenzoylglutamate ---
# Group 1 (Acetamidobenzoylglutamate) - Test: Kolmogorov-Smirnov, Stat: 0.5339, p-value: 0.0000
# Group 2 (Acetamidobenzoylglutamate) - Test: Kolmogorov-Smirnov, Stat: 0.5339, p-value: 0.0000
# Data is not normally distributed, using Mann-Whitney U Test.
# Mann-Whitney U Test result for Acetamidobenzoylglutamate:
# T-statistic/U-statistic: 18979.5000, p-value: 0.4207
# No significant difference between Group 1 and Group 2 for Acetamidobenzoylglutamate (fail to reject H0)
# ------------------------------------
# Final Report Summary:
#                        Variable Normality Test Group 1  \
# 0            Total homocysteine     Kolmogorov-Smirnov
# 1            Methylmalonic acid     Kolmogorov-Smirnov
# 2                Total cysteine     Kolmogorov-Smirnov
# 3                    Methionine     Kolmogorov-Smirnov
# 4                        Serine     Kolmogorov-Smirnov
# 5                       Glycine     Kolmogorov-Smirnov
# 6        Pyridoxal 5'-phosphate     Kolmogorov-Smirnov
# 7                     Pyridoxal     Kolmogorov-Smirnov
# 8              4-Pyridoxic acid     Kolmogorov-Smirnov
# 9                    Pyridoxine     Kolmogorov-Smirnov
# 10                     Thiamine     Kolmogorov-Smirnov
# 11       Thiamine monophosphate     Kolmogorov-Smirnov
# 12                   Riboflavin     Kolmogorov-Smirnov
# 13        Flavin mononucleotide     Kolmogorov-Smirnov
# 14                    Neopterin     Kolmogorov-Smirnov
# 15                     Cotinine     Kolmogorov-Smirnov
# 16     Trans-3'-hydroxycotinine     Kolmogorov-Smirnov
# 17                   Tryptophan     Kolmogorov-Smirnov
# 18                   Kynurenine     Kolmogorov-Smirnov
# 19          3-Hydroxykynurenine     Kolmogorov-Smirnov
# 20               Kynurenic acid     Kolmogorov-Smirnov
# 21             Xanthurenic acid     Kolmogorov-Smirnov
# 22             Anthranilic acid     Kolmogorov-Smirnov
# 23    3-Hydroxyanthranilic acid     Kolmogorov-Smirnov
# 24               Picolinic acid     Kolmogorov-Smirnov
# 25              Quinolinic acid     Kolmogorov-Smirnov
# 26               Nicotinic acid     Kolmogorov-Smirnov
# 27                 Nicotinamide     Kolmogorov-Smirnov
# 28        N1-methylnicotinamide     Kolmogorov-Smirnov
# 29                Cystathionine     Kolmogorov-Smirnov
# 30                 Trigonelline     Kolmogorov-Smirnov
# 31    5-Methyl-tetrahydrofolate     Kolmogorov-Smirnov
# 32    5-Formyl-tetrahydrofolate     Kolmogorov-Smirnov
# 33                   Folic acid     Kolmogorov-Smirnov
# 34  4-Alfa-hydroxy-5-methyl-THF     Kolmogorov-Smirnov
# 35   Para-aminobenzoylglutamate     Kolmogorov-Smirnov
# 36    Acetamidobenzoylglutamate     Kolmogorov-Smirnov
#
#     Normality p-value Group 1 Normality Test Group 2  \
# 0                         0.0     Kolmogorov-Smirnov
# 1                         0.0     Kolmogorov-Smirnov
# 2                         0.0     Kolmogorov-Smirnov
# 3                         0.0     Kolmogorov-Smirnov
# 4                         0.0     Kolmogorov-Smirnov
# 5                         0.0     Kolmogorov-Smirnov
# 6                         0.0     Kolmogorov-Smirnov
# 7                         0.0     Kolmogorov-Smirnov
# 8                         0.0     Kolmogorov-Smirnov
# 9                         0.0     Kolmogorov-Smirnov
# 10                        0.0     Kolmogorov-Smirnov
# 11                        0.0     Kolmogorov-Smirnov
# 12                        0.0     Kolmogorov-Smirnov
# 13                        0.0     Kolmogorov-Smirnov
# 14                        0.0     Kolmogorov-Smirnov
# 15                        0.0     Kolmogorov-Smirnov
# 16                        0.0     Kolmogorov-Smirnov
# 17                        0.0     Kolmogorov-Smirnov
# 18                        0.0     Kolmogorov-Smirnov
# 19                        0.0     Kolmogorov-Smirnov
# 20                        0.0     Kolmogorov-Smirnov
# 21                        0.0     Kolmogorov-Smirnov
# 22                        0.0     Kolmogorov-Smirnov
# 23                        0.0     Kolmogorov-Smirnov
# 24                        0.0     Kolmogorov-Smirnov
# 25                        0.0     Kolmogorov-Smirnov
# 26                        0.0     Kolmogorov-Smirnov
# 27                        0.0     Kolmogorov-Smirnov
# 28                        0.0     Kolmogorov-Smirnov
# 29                        0.0     Kolmogorov-Smirnov
# 30                        0.0     Kolmogorov-Smirnov
# 31                        0.0     Kolmogorov-Smirnov
# 32                        0.0     Kolmogorov-Smirnov
# 33                        0.0     Kolmogorov-Smirnov
# 34                        0.0     Kolmogorov-Smirnov
# 35                        0.0     Kolmogorov-Smirnov
# 36                        0.0     Kolmogorov-Smirnov
#
#     Normality p-value Group 2  Levene Statistic  Levene p-value  \
# 0                         0.0            1.1165          0.2913
# 1                         0.0            1.1165          0.2913
# 2                         0.0            1.1165          0.2913
# 3                         0.0            1.1165          0.2913
# 4                         0.0            1.1165          0.2913
# 5                         0.0            1.1165          0.2913
# 6                         0.0            1.1165          0.2913
# 7                         0.0            1.1165          0.2913
# 8                         0.0            1.1165          0.2913
# 9                         0.0            1.1165          0.2913
# 10                        0.0            1.1165          0.2913
# 11                        0.0            1.1165          0.2913
# 12                        0.0            1.1165          0.2913
# 13                        0.0            1.1165          0.2913
# 14                        0.0            1.1165          0.2913
# 15                        NaN            1.1165          0.2913
# 16                        0.0            1.1165          0.2913
# 17                        0.0            1.1165          0.2913
# 18                        0.0            1.1165          0.2913
# 19                        0.0            1.1165          0.2913
# 20                        0.0            1.1165          0.2913
# 21                        0.0            1.1165          0.2913
# 22                        0.0            1.1165          0.2913
# 23                        0.0            1.1165          0.2913
# 24                        0.0            1.1165          0.2913
# 25                        0.0            1.1165          0.2913
# 26                        0.0            1.1165          0.2913
# 27                        0.0            1.1165          0.2913
# 28                        0.0            1.1165          0.2913
# 29                        0.0            1.1165          0.2913
# 30                        0.0            1.1165          0.2913
# 31                        0.0            1.1165          0.2913
# 32                        0.0            1.1165          0.2913
# 33                        0.0            1.1165          0.2913
# 34                        0.0            1.1165          0.2913
# 35                        0.0            1.1165          0.2913
# 36                        0.0            1.1165          0.2913
#
#               Test Type  Test Statistic  p-value     Significance
# 0   Mann-Whitney U Test         25377.0   0.0000      Significant
# 1   Mann-Whitney U Test         23678.0   0.0011      Significant
# 2   Mann-Whitney U Test         16626.0   0.0045      Significant
# 3   Mann-Whitney U Test         30097.0   0.0000      Significant
# 4   Mann-Whitney U Test         21180.0   0.2680  Not Significant
# 5   Mann-Whitney U Test         16072.0   0.0009      Significant
# 6   Mann-Whitney U Test         22065.5   0.0607  Not Significant
# 7   Mann-Whitney U Test         24160.5   0.0002      Significant
# 8   Mann-Whitney U Test         20672.5   0.5044  Not Significant
# 9   Mann-Whitney U Test         19902.0   1.0000  Not Significant
# 10  Mann-Whitney U Test         14611.0   0.0000      Significant
# 11  Mann-Whitney U Test         16661.0   0.0050      Significant
# 12  Mann-Whitney U Test         20402.5   0.6646  Not Significant
# 13  Mann-Whitney U Test         20887.5   0.3931  Not Significant
# 14  Mann-Whitney U Test         18690.0   0.2935  Not Significant
# 15  Mann-Whitney U Test             NaN      NaN  Not Significant
# 16  Mann-Whitney U Test         20148.5   0.7895  Not Significant
# 17  Mann-Whitney U Test         26255.0   0.0000      Significant
# 18  Mann-Whitney U Test         20806.0   0.4334  Not Significant
# 19  Mann-Whitney U Test         18093.5   0.1170  Not Significant
# 20  Mann-Whitney U Test         23143.5   0.0050      Significant
# 21  Mann-Whitney U Test         27581.5   0.0000      Significant
# 22  Mann-Whitney U Test         20448.5   0.6359  Not Significant
# 23  Mann-Whitney U Test         27794.0   0.0000      Significant
# 24  Mann-Whitney U Test         27980.5   0.0000      Significant
# 25  Mann-Whitney U Test         19905.0   0.9983  Not Significant
# 26  Mann-Whitney U Test         19902.0   1.0000  Not Significant
# 27  Mann-Whitney U Test         24465.5   0.0001      Significant
# 28  Mann-Whitney U Test         21794.0   0.1010  Not Significant
# 29  Mann-Whitney U Test         22966.0   0.0079      Significant
# 30  Mann-Whitney U Test         20573.0   0.5610  Not Significant
# 31  Mann-Whitney U Test         17920.0   0.0858  Not Significant
# 32  Mann-Whitney U Test         19902.0   1.0000  Not Significant
# 33  Mann-Whitney U Test         19408.0   0.4713  Not Significant
# 34  Mann-Whitney U Test         19667.5   0.8392  Not Significant
# 35  Mann-Whitney U Test         20856.5   0.4081  Not Significant
# 36  Mann-Whitney U Test         18979.5   0.4207  Not Significant
